# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pip install camelot-py[cv] tabula-py
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.3 is available.
# ...
# You should consider upgrading via the 'c:\users\ayush\appdata\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import camelot

# %%
import pandas as pd

# %%
# !pip install ghostscript
# !pip install camelot-py[cv]
# !pip install excalibur-py
# !apt install ghostscript python3-tk
import ctypes
from ctypes.util import find_library
find_library("".join(("gsdll", str(ctypes.sizeof(ctypes.c_voidp) * 8), ".dll")))
# Out:
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\users\ayush\appdata\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\users\ayush\appdata\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.3; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\users\ayush\appdata\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
table = camelot.read_pdf('C:/Users/AYUSH/Downloads/100100502_AES01267KY_ORG_Financial-Statement_2020.pdf',flavor='stream', pages='1-5')

# %%
table[3].df
# Out:
#                                                     0      1  \
# 0
# 1                                         Particulars  notes
# 2
# 3                                              Assets
# 4                              non - Current Assets :
# ..                                                ...    ...
# 59                       Income Tax Liabilities (Net)     29
# 60                          total Current Liabilities
# 61                                  total Liabilities
# 62                       total equity and Liabilities
# 63  See Accompanying Notes forming part of the Con...
#
#                    2                 3
# 0                       (` in Million)
# 1              As at             As at
# 2   31st March, 2020  31st March, 2019
# 3
# 4
# ..               ...               ...
# 59             95.94              0.02
# 60          4,945.13          4,107.49
# 61          5,328.48          4,683.72
# 62         14,695.47         12,986.58
# 63
#
# ...

# %%
table[4].df
# Out:
#                                                     0      1                2  \
# 0
# 1                                         PArtICuLArs  notes       Year ended
# 2                                                             31st March 2020
# 3                                              InCoMe
# 4                             Revenue from Operations     30        13,748.19
# 5                                        Other Income     31           103.98
# 6                                        total Income               13,852.17
# 7                                            exPenses
# 8                      Cost of Raw Materials Consumed     32         8,078.77
# 9                         Purchases of Stock-in Trade     33           712.02
# 10  Changes in Inventories of Finished Goods, Work...     34            41.91
# 11                          Employee Benefits Expense     35           871.27
# 12                                      Finance Costs     36           190.26
# ...

# %%
table[3].to_csv(r'C:/Users/AYUSH/Downloads/Consolidated_bank_statement.csv', index = False)

# %%
table[4].to_csv(r'C:/Users/AYUSH/Downloads/Consolidated_Profit_and_Loss.csv', index = False)
